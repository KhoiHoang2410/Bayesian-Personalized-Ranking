# %%
# Load các thư viện cần thiết
import os
import math
import pickle
import pathlib
import numpy as np
import pandas as pd
from time import time
from datetime import datetime
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
from scipy.sparse import csr_matrix, dok_matrix
from sklearn.metrics import mean_squared_error

np.random.seed(12)

# %%
def load_behaviors(path):
    df = pd.read_csv(
        path,
        sep='\t',
        names = ["id", "user_id", 'created_at', "history", "impressions"]
    )
    return df

def write_file(df, path):
    t_start = time()
    print("Processing", path)
    with open(path, "w") as file:
        for i, row in df.iterrows():
            for new_id in str(row.history).split(' '):
                if row.user_id[1:].isnumeric() and new_id[1:].isnumeric():
                    file.write(row.user_id[1:] + "," + new_id[1:] + "\n")

    t_end = time()
    print("Processed in: {:.2f} Seconds".format(t_end - t_start))

def write_data_file(train_path, output_train_path):
    train_df = load_behaviors(train_path)

    write_file(train_df, output_train_path)
    
def load_file(path):
    df = pd.read_csv(
        path,
        header=None,
        names=['user_id', 'item_id']
    )
    df.reindex(columns = ['user_id', 'item_id'])
    return df.reset_index(drop = True)

def load_data(train_path):
    train_df = load_file(train_path)
    
    return train_df

def filter_df(df, user_min, item_min):
    if df is None:
        return

    t_start = time()

    user_counts = df.groupby("user_id").size()
    user_subset = np.in1d(
        df.user_id, user_counts[user_counts >= item_min].index
    )

    filter_df = df[user_subset].reset_index(drop=True)

    # find items with 10 or more users
    item_counts = filter_df.groupby("item_id").size()
    item_subset = np.in1d(
        filter_df.item_id, item_counts[item_counts >= user_min].index
    )

    filter_df = filter_df[item_subset].reset_index(drop=True)

    user_counts = filter_df.groupby("user_id").size()
    user_subset = np.in1d(filter_df.user_id, user_counts[user_counts >= item_min].index)

    filter_df = filter_df[user_subset].reset_index(drop=True)

    t_end = time()

#     assert (filter_df.groupby("user_id").size() < 5).sum() == 0
#     assert (filter_df.groupby("item_id").size() < 5).sum() == 0

    print(filter_df.nunique())
    print(filter_df.shape)
    print("{:.2f} Seconds".format(t_end - t_start))

    return filter_df

def reset_df(df):
    item_enc = LabelEncoder()
    df['news_id'] = df["item_id"]
    df["item_id"] = item_enc.fit_transform(df["item_id"])

    user_enc = LabelEncoder()
    df["user_id"] = user_enc.fit_transform(df["user_id"])

    assert df.user_id.min() == 0
    assert df.item_id.min() == 0

    return df

def convert_to_bpr_mat(dataframe, threshold = 3):
    tempdf = dataframe.copy()

    # Vì tập dữ liệu này đánh index từ 1 nên chuyển sang kiểu category
    # để tránh việc chúng ta có ma trận
    tempdf['user_id'] = tempdf['user_id'].astype('category')
    tempdf['item_id'] = tempdf['item_id'].astype('category')
    tempdf['positive'] = 1

    bpr_mat = csr_matrix((tempdf['positive'], (tempdf['user_id'].cat.codes, tempdf['item_id'].cat.codes)))
    bpr_mat.eliminate_zeros()
    del tempdf
    return bpr_mat

def split_to_train_test(bpr_mat, test_ratio = 0.2, verbose=True):
    """
    Chia tập dữ liệu ra thành tập train & tập test

    :param bpr_mat: ma trận bpr
    :param test_ratio: float - tỉ lệ test set

    :return train: ma trận bpr train
    :return test: ma trận bpr test
    """
    # Số lượng người dùng
    n_users = bpr_mat.shape[0]
    # Dùng ma trận thưa Dictionary Of Keys tối ưu hơn cho công đoạn này
    train = bpr_mat.copy().todok()
    test = dok_matrix(train.shape) # Lưu ý hiện tại test là ma trận 0

    # với mỗi người dùng u
    # chia số trường hợp nên khuyến nghị với tỉ lệ test_ratio đươc cho
    # phần nào thuộc về test
    for u in range(n_users):
        split_index = bpr_mat[u].indices
        # đếm số trường hợp nên khuyến nghị
        count_positive = split_index.shape[0]
        n_splits = max(min(math.ceil(test_ratio * count_positive), count_positive - 1), 1)
        test_index = np.random.choice(split_index, size=n_splits, replace=False)
        # Xem như dữ liệu chưa biết trong tập train
        train[u, test_index] = 0
        # Xem như dữ liệu nhìn thấy trong tập test
        test[u, test_index] = 1

    train, test = train.tocsr(), test.tocsr()

    # Nếu cần in thông tin ra ngoài
    if verbose:
        print('BPR matrix with %d stored elements' % bpr_mat.nnz)
        print('Train matrix with %d stored elements' % train.nnz)
        print('Test matrix with %d stored elements' % test.nnz)
    return train, test

def predict_bpr(W, H, user=None):
    """
    Hàm trả về X_hat

    :param W: ma trận W từ MF
    :param H: ma trận H từ MF
    :param user: người dùng (nếu None mặt định trả về tất cả)

    :return predict_scores: điểm dự đoán từ BPR MF
    """
    if user is None:
        return W @ H.T
    else:
        return W[user] @ H.T

def auc_score(predict_mat, bpr_mat):
    """
    Tính Area under the ROC curve (AUC)
    cho bài toán hệ khuyến nghị

    :param predict_mat: ma trận dữ đoán bpr mf
    :param bpr_mat: ma trận train hoặc test
    :return auc: area under the roc curve
    """
    auc = 0.0
    n_users, n_items = bpr_mat.shape

    # u và row tương ứng user và bp
    for u in range(n_users):
        y_pred = predict_mat[u]
        y_true = np.zeros(n_items)
        y_true[bpr_mat[u].indices] = 1
        try:
            auc += roc_auc_score(y_true, y_pred)
        except ValueError:
            continue
    auc /= n_users
    return auc

def calc_error(W, H, pos):
    n_user = len(pos)
    pred = []
    result = []
    print('calculating MSE error - ', end = '')
    for u in range(n_user):
        predict_u = predict_bpr(W, H, user=u)

        argsort_predict_u = np.flip(np.argsort(predict_u))
        intersect = np.intersect1d(argsort_predict_u[:len(pos[u])], pos[u])
        pred.append(intersect.size)
        result.append(pos[u].size)
    print(mean_squared_error(pred, result))

def learn_bpr_mf_sgd(bpr_mat, pos, neg, W = None, H = None, alpha=0.01, lamb=0.01, k=12, n_iters=10000, initial_value=2):
    """
    Thuật toán học BPR MF SGD (một điểm dữ liệu duy nhất)

    :param bpr_mat: ma trận bpr
    :param alpha: hệ số learning rate
    :param lamb: hệ số lambda của bình thường hóa regularization
    :param k: số lượng latent factor trong bài toán MF
    :param n_iters: số vòng lặp

    :return W: ma trận W
    :return H: ma trận H
    """
    
    n_users, n_items = bpr_mat.shape
    # Khởi tạo ma trận W và ma trận H
    if W is None:
        W = np.empty(shape=(n_users, k))
        W.fill(initial_value)
    if H is None:
        H = np.empty(shape=(n_items, k))
        H.fill(initial_value)

    # lặp
    for idx in range(n_iters):
        # ngẫu nghiên 3 bộ (u,i,j) từ D_S
        u = np.random.randint(0, n_users)
        if len(pos[u]) == 0:
            continue
        i = pos[u][np.random.randint(0, len(pos[u]))]
        j = neg[u][np.random.randint(0, len(neg[u]))]

        # Tính xuij
        xui = (W[u] * H[i]).sum()
        xuj = (W[u] * H[j]).sum()
        xuij = xui - xuj

        # mũ tự nhiên e của xuij
        exp_xuij = np.exp(xuij)

        # sgd cho tham số Theta (W và H)
        W[u] = W[u] + alpha * ( exp_xuij / (1+exp_xuij) * (H[i] - H[j]) + lamb * W[u])
        H[i] = H[i] + alpha * ( exp_xuij / (1+exp_xuij) * W[u] + lamb * H[i])
        H[j] = H[j] + alpha * ( exp_xuij / (1+exp_xuij) * (-W[u]) + lamb * H[j])

        if (idx + 1) % 10000 == 0:
            print('Iter: %i' % (idx + 1))
            calc_error(W, H, pos)
    return W, H

# %%
train_path = './MINDsmall_train/behaviors.tsv'
output_train_path = './datafile/small_train.csv'

result_train_file = 'bpr_mf'

test_ratio = 0.3

alpha=0.001
lamb=0.02
k=60
training_per_interact = 3
initial_value = 1
fine_and_reward = 0.3

# %%
# write_data_file(train_path, output_train_path)
train_df = load_data(output_train_path)

user_min = int(train_df.groupby("user_id").size().mean())
item_min = int(train_df.groupby("item_id").size().mean())

print('user min: %i\nitem min: %i' % (user_min, item_min))

# Filter by user_min and item_min
filtered_df = reset_df(filter_df(train_df, user_min, item_min))
bpr_mat = convert_to_bpr_mat(filtered_df)
print(bpr_mat.shape)
# Out:
# user min: 104
# item min: 153
# user_id    6124
# item_id    6463
# dtype: int64
# (3285644, 2)
# 1.01 Seconds
# (6124, 6463)

# %%
for i in range(10):
    k = 60 + i * 20
    # Split to train and test
    bpr_train, bpr_test = split_to_train_test(bpr_mat, test_ratio=test_ratio, verbose=True)

    n_iters = training_per_interact * bpr_train.nnz
    print('n iters: %i' % n_iters)

    # Prepare to train
    W, H = None, None
    pos = np.split(bpr_train.indices, bpr_train.indptr)[1:-1]
    neg = [np.setdiff1d(np.arange(0, bpr_train.shape[1], 1), e) for e in pos]

    W, H = learn_bpr_mf_sgd(
        bpr_train,
        pos,
        neg,
        W = W,
        H = H,
        alpha=alpha,
        lamb=lamb,
        k=k,
        n_iters=n_iters,
        initial_value = initial_value
    )

    pred = predict_bpr(W, H)

    train_score = auc_score(pred, bpr_train)
    test_score = auc_score(pred, bpr_test)
    print('AUC of train: %f' % train_score)
    print('AUC of test : %f' % test_score)

    output_folder = os.path.join('./result', datetime.now().strftime("%d-%m-%Y %H-%M-%S"))

    pathlib.Path(output_folder).mkdir(parents=True, exist_ok=True)

    np.save(os.path.join(output_folder, result_train_file + '_W.npy'), W)
    np.save(os.path.join(output_folder, result_train_file + '_H.npy'), H)

    with open(os.path.join(output_folder, result_train_file + '.txt'), 'w') as file:
        file.write("Parameters:\n\n")
        file.write('user min: %i' % user_min + "\n")
        file.write('item min: %i' % item_min + "\n")
        file.write('test ratio: %f' % test_ratio + "\n")
        file.write('alpha: %f' % alpha + "\n")
        file.write('lambda: %f' % lamb + "\n")
        file.write('k: %i' % k + "\n")
        file.write('n iters: %i' % n_iters + "\n")
        file.write('AUC-Train: %f' % train_score + "\n")
        file.write('AUC-Test: %f' % test_score + "\n")
        file.write("---------------------\n")
        file.write('Total users: %i \n' % train_df.nunique()[0])
        file.write('Total items: %i \n' % train_df.nunique()[1])
        file.write('Total interacts: %i \n' % train_df.shape[0])
        file.write('No training users: %i \n' % filtered_df.nunique()[0])
        file.write('No training items: %i \n' % filtered_df.nunique()[1])
        file.write('BPR matrix with %d stored elements\n' % bpr_mat.nnz)
        file.write('Train matrix with %d stored elements\n' % bpr_train.nnz)
        file.write('Test matrix with %d stored elements\n' % bpr_test.nnz)
# Out:
# BPR matrix with 335627 stored elements
# Train matrix with 232200 stored elements
# Test matrix with 103427 stored elements
# n iters: 696600
# Iter: 10000
# calculating MSE error - 1620.5860548661005
# Iter: 20000
# calculating MSE error - 1611.8296864794252
# Iter: 30000
# calculating MSE error - 1609.7256694970608
# Iter: 40000
# calculating MSE error - 1608.0760940561725
# Iter: 50000
# calculating MSE error - 1607.1752122795558
# Iter: 60000
# calculating MSE error - 1606.5711952971915
# Iter: 70000
# calculating MSE error - 1605.1143043762247
# Iter: 80000
# calculating MSE error - 1604.8412802090138
# Iter: 90000
# calculating MSE error - 1604.6694970607446
# Iter: 100000
# calculating MSE error - 1603.477465708687
# Iter: 110000
# calculating MSE error - 1603.9083932070541
# Iter: 120000
# calculating MSE error - 1604.8806335728282
# Iter: 130000
# calculating MSE error - 1605.1090790333117
# Iter: 140000
# calculating MSE error - 1604.8079686479425
# Iter: 150000
# calculating MSE error - 1604.3313193990855
# Iter: 160000
# calculating MSE error - 1603.985630306989
# Iter: 170000
# calculating MSE error - 1603.740039190072
# Iter: 180000
# calculating MSE error - 1603.9516655780535
# Iter: 190000
# calculating MSE error - 1604.5917700849118
# Iter: 200000
# calculating MSE error - 1604.6520248203788
# Iter: 210000
# calculating MSE error - 1605.028086218158
# Iter: 220000
# calculating MSE error - 1605.15692357936
# Iter: 230000
# calculating MSE error - 1604.814826910516
# Iter: 240000
# calculating MSE error - 1604.778086218158
# Iter: 250000
# calculating MSE error - 1604.046048334422
# Iter: 260000
# calculating MSE error - 1604.1265512736773
# Iter: 270000
# calculating MSE error - 1604.4588504245592
# Iter: 280000
# calculating MSE error - 1604.5483344219465
# Iter: 290000
# calculating MSE error - 1604.810581319399
# Iter: 300000
# calculating MSE error - 1604.4830176355324
# Iter: 310000
# calculating MSE error - 1605.0251469627694
# Iter: 320000
# calculating MSE error - 1604.930274330503
# Iter: 330000
# calculating MSE error - 1604.990365774004
# Iter: 340000
# calculating MSE error - 1604.7000326583932
# Iter: 350000
# calculating MSE error - 1604.602057478772
# Iter: 360000
# calculating MSE error - 1604.5063683866754
# Iter: 370000
# calculating MSE error - 1604.263879817113
# Iter: 380000
# calculating MSE error - 1604.4403984323972
# Iter: 390000
# calculating MSE error - 1605.0360875244937
# Iter: 400000
# calculating MSE error - 1604.7557152188112
# Iter: 410000
# calculating MSE error - 1604.0107772697584
# Iter: 420000
# calculating MSE error - 1603.879163945134
# Iter: 430000
# calculating MSE error - 1603.7707380796865
# Iter: 440000
# calculating MSE error - 1603.5571521881122
# Iter: 450000
# calculating MSE error - 1603.957544088831
# Iter: 460000
# calculating MSE error - 1603.8176028739385
# Iter: 470000
# calculating MSE error - 1603.7379163945134
# Iter: 480000
# calculating MSE error - 1603.7320378837362
# Iter: 490000
# calculating MSE error - 1604.0437622468974
# Iter: 500000
# calculating MSE error - 1604.1673742651863
# Iter: 510000
# calculating MSE error - 1603.8517308948399
# Iter: 520000
# calculating MSE error - 1603.9648922273025
# Iter: 530000
# calculating MSE error - 1603.745591116917
# Iter: 540000
# calculating MSE error - 1603.8972893533637
# Iter: 550000
# calculating MSE error - 1603.8865120836056
# Iter: 560000
# calculating MSE error - 1603.9657086871325
# Iter: 570000
# calculating MSE error - 1604.6283474853037
# Iter: 580000
# calculating MSE error - 1604.2792292619204
# Iter: 590000
# calculating MSE error - 1604.2789026779883
# Iter: 600000
# calculating MSE error - 1604.171619856303
# Iter: 610000
# calculating MSE error - 1604.4833442194645
# Iter: 620000
# calculating MSE error - 1604.3598954931417
# Iter: 630000
# calculating MSE error - 1604.7179947746572
# Iter: 640000
# calculating MSE error - 1604.84307642064
# Iter: 650000
# calculating MSE error - 1604.6265512736773
# Iter: 660000
# calculating MSE error - 1604.7003592423252
# Iter: 670000
# calculating MSE error - 1604.5661332462444
# Iter: 680000
# calculating MSE error - 1604.5769105160025
# Iter: 690000
# calculating MSE error - 1604.6278576094055
# AUC of train: 0.776100
# AUC of test : 0.765519
# BPR matrix with 335627 stored elements
# Train matrix with 232200 stored elements
# Test matrix with 103427 stored elements
# n iters: 696600
# Iter: 10000
# calculating MSE error - 1633.791476159373
# Iter: 20000
# calculating MSE error - 1623.9753429131288
# Iter: 30000
# calculating MSE error - 1618.4234160679296
# Iter: 40000
# calculating MSE error - 1615.4790986283474
# Iter: 50000
# calculating MSE error - 1612.926028739386
# Iter: 60000
# calculating MSE error - 1610.6510450685826
# Iter: 70000
# calculating MSE error - 1610.3584258654473
# Iter: 80000
# calculating MSE error - 1610.852057478772
# Iter: 90000
# calculating MSE error - 1610.6886022207707
# Iter: 100000
# calculating MSE error - 1610.587851077727
# Iter: 110000
# calculating MSE error - 1611.1781515349444
# Iter: 120000
# calculating MSE error - 1610.4559111691706
# Iter: 130000
# calculating MSE error - 1610.791802743305
# Iter: 140000
# calculating MSE error - 1610.6126714565644
# Iter: 150000
# calculating MSE error - 1609.8528739386022
# Iter: 160000
# calculating MSE error - 1610.3363814500326
# Iter: 170000
# calculating MSE error - 1609.9652188112345
# Iter: 180000
# calculating MSE error - 1609.518451992162
# Iter: 190000
# calculating MSE error - 1610.0347811887655
# Iter: 200000
# calculating MSE error - 1609.6438602220771
# Iter: 210000
# calculating MSE error - 1609.601241018942
# Iter: 220000
# calculating MSE error - 1609.588177661659
# Iter: 230000
# calculating MSE error - 1609.3620182887003
# Iter: 240000
# calculating MSE error - 1609.009144350098
# Iter: 250000
# calculating MSE error - 1609.3453625081645
# Iter: 260000
# calculating MSE error - 1609.0571521881122
# Iter: 270000
# calculating MSE error - 1609.5362508164599
# Iter: 280000
# calculating MSE error - 1609.3812867406923
# Iter: 290000
# calculating MSE error - 1608.999673416068
# Iter: 300000
# calculating MSE error - 1609.3723056825604
# Iter: 310000
# calculating MSE error - 1608.944480731548
# Iter: 320000
# calculating MSE error - 1609.3999020248204
# Iter: 330000
# calculating MSE error - 1609.5489875898106
# Iter: 340000
# calculating MSE error - 1609.6822338340953
# Iter: 350000
# calculating MSE error - 1609.7379163945134
# Iter: 360000
# calculating MSE error - 1609.7032984977138
# Iter: 370000
# calculating MSE error - 1609.9882429784454
# Iter: 380000
# calculating MSE error - 1609.421783148269
# Iter: 390000
# calculating MSE error - 1609.737099934683
# Iter: 400000
# calculating MSE error - 1609.703951665578
# Iter: 410000
# calculating MSE error - 1609.486120182887
# Iter: 420000
# calculating MSE error - 1609.504735467015
# Iter: 430000
# calculating MSE error - 1609.709013716525
# Iter: 440000
# calculating MSE error - 1609.490039190072
# Iter: 450000
# calculating MSE error - 1609.153004572175
# Iter: 460000
# calculating MSE error - 1609.5382103200523
# Iter: 470000
# calculating MSE error - 1609.4126387981712
# Iter: 480000
# calculating MSE error - 1609.4526453298497
# Iter: 490000
# calculating MSE error - 1609.3876551273677
# Iter: 500000
# calculating MSE error - 1609.4292945787067
# Iter: 510000
# calculating MSE error - 1609.629980404964
# Iter: 520000
# calculating MSE error - 1609.6742325277596
# Iter: 530000
# calculating MSE error - 1609.3502612671457
# Iter: 540000
# calculating MSE error - 1609.0192684519923
# Iter: 550000
# calculating MSE error - 1609.074624428478
# Iter: 560000
# calculating MSE error - 1609.2890267798825
# Iter: 570000
# calculating MSE error - 1609.3672436316133
# Iter: 580000
# calculating MSE error - 1609.2488569562377
# Iter: 590000
# calculating MSE error - 1609.2601241018942
# Iter: 600000
# calculating MSE error - 1609.2197909862834
# Iter: 610000
# calculating MSE error - 1608.879653821032
# Iter: 620000
# calculating MSE error - 1609.0080013063357
# Iter: 630000
# calculating MSE error - 1609.3437295885042
# Iter: 640000
# calculating MSE error - 1609.2207707380796
# Iter: 650000
# calculating MSE error - 1609.1270411495755
# Iter: 660000
# calculating MSE error - 1609.499673416068
# Iter: 670000
# calculating MSE error - 1609.4211299804049
# Iter: 680000
# calculating MSE error - 1609.2702482037885
# Iter: 690000
# calculating MSE error - 1609.3905943827563
# AUC of train: 0.775505
# AUC of test : 0.764421
# BPR matrix with 335627 stored elements
# Train matrix with 232200 stored elements
# Test matrix with 103427 stored elements
# n iters: 696600
# Iter: 10000
# calculating MSE error - 1620.551110385369
# Iter: 20000
# calculating MSE error - 1612.7896799477467
# Iter: 30000
# calculating MSE error - 1608.9167210973221
# Iter: 40000
# calculating MSE error - 1610.494774657087
# Iter: 50000
# calculating MSE error - 1608.948726322665
# Iter: 60000
# calculating MSE error - 1607.1126714565644
# Iter: 70000
# calculating MSE error - 1606.2726975832788
# Iter: 80000
# calculating MSE error - 1605.9415414761593
# Iter: 90000
# calculating MSE error - 1605.0452318745918
# Iter: 100000
# calculating MSE error - 1604.995917700849
# Iter: 110000
# calculating MSE error - 1604.513716525147
# Iter: 120000
# calculating MSE error - 1604.7013389941214
# Iter: 130000
# calculating MSE error - 1604.2998040496407
# Iter: 140000
# calculating MSE error - 1604.6791312867406
# Iter: 150000
# calculating MSE error - 1604.2849444807316
# Iter: 160000
# calculating MSE error - 1604.944644023514
# Iter: 170000
# calculating MSE error - 1604.7712279555847
# Iter: 180000
# calculating MSE error - 1604.7294252122795
# Iter: 190000
# calculating MSE error - 1604.8189092096668
# Iter: 200000
# calculating MSE error - 1604.5992815153495
# Iter: 210000
# calculating MSE error - 1604.735956890921
# Iter: 220000
# calculating MSE error - 1605.0070215545395
# Iter: 230000
# calculating MSE error - 1604.592423252776
# Iter: 240000
# calculating MSE error - 1604.847811887655
# Iter: 250000
# calculating MSE error - 1604.356792945787
# Iter: 260000
# calculating MSE error - 1604.5107772697584
# Iter: 270000
# calculating MSE error - 1604.6410842586545
# Iter: 280000
# calculating MSE error - 1605.6415741345527
# Iter: 290000
# calculating MSE error - 1605.671293272371
# Iter: 300000
# calculating MSE error - 1605.2642064010452
# Iter: 310000
# calculating MSE error - 1604.6663945133898
# Iter: 320000
# calculating MSE error - 1605.0364141084258
# Iter: 330000
# calculating MSE error - 1604.8692031352057
# Iter: 340000
# calculating MSE error - 1605.2846178967995
# Iter: 350000
# calculating MSE error - 1605.22158719791
# Iter: 360000
# calculating MSE error - 1604.9802416721097
# Iter: 370000
# calculating MSE error - 1605.1368386675376
# Iter: 380000
# calculating MSE error - 1604.9807315480077
# Iter: 390000
# calculating MSE error - 1604.8595689092097
# Iter: 400000
# calculating MSE error - 1604.6245917700849
# Iter: 410000
# calculating MSE error - 1604.3786740692358
# Iter: 420000
# calculating MSE error - 1604.6353690398432
# Iter: 430000
# calculating MSE error - 1604.3574461136511
# Iter: 440000
# calculating MSE error - 1604.5101241018942
# Iter: 450000
# calculating MSE error - 1604.7976812540824
# Iter: 460000
# calculating MSE error - 1604.7142390594383
# Iter: 470000
# calculating MSE error - 1604.5822991508817
# Iter: 480000
# calculating MSE error - 1604.555355976486
# Iter: 490000
# calculating MSE error - 1604.7253429131288
# Iter: 500000
# calculating MSE error - 1604.5940561724362
# Iter: 510000
# calculating MSE error - 1604.6755388634879
# Iter: 520000
# calculating MSE error - 1604.6641084258654
# Iter: 530000
# calculating MSE error - 1604.5285760940562
# Iter: 540000
# calculating MSE error - 1604.9462769431743
# Iter: 550000
# calculating MSE error - 1604.8231548007839
# Iter: 560000
# calculating MSE error - 1605.088667537557
# Iter: 570000
# calculating MSE error - 1604.791476159373
# Iter: 580000
# calculating MSE error - 1604.453951665578
# Iter: 590000
# calculating MSE error - 1604.342586544742
# Iter: 600000
# calculating MSE error - 1604.2060744611365
# Iter: 610000
# calculating MSE error - 1604.087524493795
# Iter: 620000
# calculating MSE error - 1604.3264206401045
# Iter: 630000
# calculating MSE error - 1604.1151208360548
# Iter: 640000
# calculating MSE error - 1604.180927498367
# Iter: 650000
# calculating MSE error - 1604.1727629000652
# Iter: 660000
# calculating MSE error - 1604.199052906597
# Iter: 670000
# calculating MSE error - 1604.106466361855
# Iter: 680000
# calculating MSE error - 1604.0715218811235
# Iter: 690000
# calculating MSE error - 1604.0708687132594
# AUC of train: 0.775068
# AUC of test : 0.765136
# BPR matrix with 335627 stored elements
# Train matrix with 232200 stored elements
# Test matrix with 103427 stored elements
# n iters: 696600
# Iter: 10000
# calculating MSE error - 1623.2468974526453
# Iter: 20000
# calculating MSE error - 1612.4990202482038
# Iter: 30000
# calculating MSE error - 1607.6681907250163
# Iter: 40000
# calculating MSE error - 1606.004898758981
# Iter: 50000
# calculating MSE error - 1606.8848791639452
# Iter: 60000
# calculating MSE error - 1605.7354670150228
# Iter: 70000
# calculating MSE error - 1606.0483344219465
# Iter: 80000
# calculating MSE error - 1606.711952971914
# Iter: 90000
# calculating MSE error - 1605.865447419987
# Iter: 100000
# calculating MSE error - 1605.6004245591116
# Iter: 110000
# calculating MSE error - 1605.3770411495755
# Iter: 120000
# calculating MSE error - 1604.8536903984325
# Iter: 130000
# calculating MSE error - 1605.2715545395167
# Iter: 140000
# calculating MSE error - 1604.762900065317
# Iter: 150000
# calculating MSE error - 1604.3340953625082
# Iter: 160000
# calculating MSE error - 1603.5862181580667
# Iter: 170000
# calculating MSE error - 1604.236773350751
# Iter: 180000
# calculating MSE error - 1604.7150555192684
# Iter: 190000
# calculating MSE error - 1604.0429457870673
# Iter: 200000
# calculating MSE error - 1603.71293272371
# Iter: 210000
# calculating MSE error -
